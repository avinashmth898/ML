# %%
import random
import scipy
import numpy as np
import matplotlib.pyplot as plt

# %%
x= np.arange(0,10,0.125)

mean= 5
sigma= 1

gd=(1/(np.sqrt(2*np.pi)*sigma))*np.exp(-((x-mean)**2/2*(sigma**2)))


plt.plot(x,gd);

# %%
g= np.random.normal(5,1,size=(1,10))
g
# Out:
# array([[5.01997461, 4.87693417, 4.06304299, 3.60004246, 4.87524951,
#         4.54744375, 3.47201536, 4.82774703, 4.0061109 , 3.68976542]])

# %%
x=g[0]
gd=(1/(np.sqrt(2*np.pi)*sigma))*np.exp(-((x-mean)**2/2*(sigma**2)))
plt.plot(x,gd,"bo")

# %%
x =g[0]
x = np.sort(x)
gd = ( 1/(np.sqrt(2*np.pi)*sigma) ) * np.exp( -((x-mean)**2/2*(sigma**2)) )
fig, ax = plt.subplots(3, 4, figsize=(20, 10))
mean = 0
sigma = 1
y = np.arange(0,10,0.125)
for i in range(0,3):
 for j in range(0,4):
  y_gd = ( 1/(np.sqrt(2*np.pi)*sigma) ) * np.exp( -((y-mean)**2/2*(sigma**2)) )
  ax[i , j].plot(x, gd,'ro')
  ax[i , j].plot(y,y_gd)
  ax[i , j].set_title("Mean = " + str(mean) )
  
  while mean<=9
  mean = mean + 1
